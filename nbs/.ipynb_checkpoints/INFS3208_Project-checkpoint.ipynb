# %% [markdown]
# ### Prepare for dataset

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, unix_timestamp, to_date, when, count, sum
spark = SparkSession.builder.appName('housing_prices').getOrCreate()
housing_data = spark.read.csv('hdfs://namenode/full_housing_prices.csv', header = True, inferSchema = True)
housing_data.printSchema()
# Out:
# root
#  |-- Suburb: string (nullable = true)
#  |-- Address: string (nullable = true)
#  |-- Rooms: integer (nullable = true)
#  |-- Type: string (nullable = true)
#  |-- Price: integer (nullable = true)
#  |-- Method: string (nullable = true)
#  |-- SellerG: string (nullable = true)
#  |-- Date: string (nullable = true)
#  |-- Distance: string (nullable = true)
#  |-- Postcode: string (nullable = true)
#  |-- Bedroom2: integer (nullable = true)
#  |-- Bathroom: integer (nullable = true)
#  |-- Car: integer (nullable = true)
#  |-- Landsize: integer (nullable = true)
#  |-- BuildingArea: double (nullable = true)
#  |-- YearBuilt: integer (nullable = true)
#  |-- CouncilArea: string (nullable = true)
#  |-- Lattitude: double (nullable = true)
#  |-- Longtitude: double (nullable = true)
#  |-- Regionname: string (nullable = true)
#  |-- Propertycount: string (nullable = true)

# %% [markdown]
# We can see that Date is being treated as a string. Since we want to compare the dates, we will cast it to the date type.

# %%
housing_data = housing_data.withColumn('Date', to_date(unix_timestamp(col('Date'), 'd/MM/yyyy').cast("timestamp")))
housing_data = housing_data.withColumn('Distance', col('Distance').cast("double"))
housing_data.printSchema()
# Out:
# root
#  |-- Suburb: string (nullable = true)
#  |-- Address: string (nullable = true)
#  |-- Rooms: integer (nullable = true)
#  |-- Type: string (nullable = true)
#  |-- Price: integer (nullable = true)
#  |-- Method: string (nullable = true)
#  |-- SellerG: string (nullable = true)
#  |-- Date: date (nullable = true)
#  |-- Distance: double (nullable = true)
#  |-- Postcode: string (nullable = true)
#  |-- Bedroom2: integer (nullable = true)
#  |-- Bathroom: integer (nullable = true)
#  |-- Car: integer (nullable = true)
#  |-- Landsize: integer (nullable = true)
#  |-- BuildingArea: double (nullable = true)
#  |-- YearBuilt: integer (nullable = true)
#  |-- CouncilArea: string (nullable = true)
#  |-- Lattitude: double (nullable = true)
#  |-- Longtitude: double (nullable = true)
#  |-- Regionname: string (nullable = true)
#  |-- Propertycount: string (nullable = true)

# %% [markdown]
# ### Data Exploration and Preprocessing
# Since we are aiming to predict the price of the houses based on the housing data, we will drop rows where the price is unknown.

# %%
housing_data = housing_data.where(col("Price").isNotNull())

# %%
import pandas as pd
pd.DataFrame(housing_data.take(5), columns=housing_data.columns).transpose()
# Out:
#                                    0                      1  \
# Suburb                    Abbotsford             Abbotsford
# Address                 85 Turner St        25 Bloomburg St
# Rooms                              2                      2
# Type                               h                      h
# Price                        1480000                1035000
# Method                             S                      S
# SellerG                       Biggin                 Biggin
# Date                      2016-12-03             2016-02-04
# Distance                         2.5                    2.5
# Postcode                        3067                   3067
# Bedroom2                           2                      2
# Bathroom                           1                      1
# Car                                1                      0
# Landsize                         202                    156
# BuildingArea                     NaN                     79
# YearBuilt                        NaN                   1900
# CouncilArea       Yarra City Council     Yarra City Council
# Lattitude                   -37.7996               -37.8079
# Longtitude                   144.998                144.993
# Regionname     Northern Metropolitan  Northern Metropolitan
# Propertycount                   4019                   4019
#
#                                    2                      3  \
# Suburb                    Abbotsford             Abbotsford
# Address                 5 Charles St       40 Federation La
# Rooms                              3                      3
# Type                               h                      h
# Price                        1465000                 850000
# Method                            SP                     PI
# SellerG                       Biggin                 Biggin
# Date                      2017-03-04             2017-03-04
# Distance                         2.5                    2.5
# Postcode                        3067                   3067
# Bedroom2                           3                      3
# Bathroom                           2                      2
# Car                                0                      1
# Landsize                         134                     94
# BuildingArea                     150                    NaN
# YearBuilt                       1900                    NaN
# CouncilArea       Yarra City Council     Yarra City Council
# Lattitude                   -37.8093               -37.7969
# Longtitude                   144.994                144.997
# Regionname     Northern Metropolitan  Northern Metropolitan
# Propertycount                   4019                   4019
#
#                                    4
# Suburb                    Abbotsford
# Address                  55a Park St
# Rooms                              4
# Type                               h
# Price                        1600000
# Method                            VB
# SellerG                       Nelson
# Date                      2016-06-04
# Distance                         2.5
# Postcode                        3067
# Bedroom2                           3
# Bathroom                           1
# Car                                2
# Landsize                         120
# BuildingArea                     142
# YearBuilt                       2014
# CouncilArea       Yarra City Council
# Lattitude                   -37.8072
# Longtitude                   144.994
# Regionname     Northern Metropolitan
# Propertycount                   4019

# %%
numeric_features = [t[0] for t in housing_data.dtypes if t[1] == 'int' or t[1] == 'double']
housing_data.select(numeric_features).describe().toPandas().transpose()
# Out:
#                   0                   1                    2          3  \
# summary       count                mean               stddev        min
# Rooms         27247  2.9922927294748045    0.954795295019432          1
# Price         27247   1050173.344955408    641467.1301045996      85000
# Distance      27246  11.280276003817045    6.787468996334044        0.0
# Bedroom2      20806  3.0462366625012014   0.9551217965638036          0
# Bathroom      20800  1.5916826923076923   0.7008803646354183          0
# Car           20423  1.7153699260637516   0.9942160951843622          0
# Landsize      17982   593.4889333778223    3757.266428643432          0
# BuildingArea  10656  156.83458555743243    449.2227905392576        0.0
# YearBuilt     12084  1966.6091525984773    36.76237302581703       1196
# Lattitude     20993  -37.80696302719973  0.09161945473704548  -38.19043
# Longtitude    20993  144.99671101938694  0.12068029585147116  144.42379
#
#                       4
# summary             max
# Rooms                16
# Price          11200000
# Distance           48.1
# Bedroom2             20
# Bathroom              9
# Car                  18
# Landsize         433014
# BuildingArea    44515.0
# YearBuilt          2019
# Lattitude      -37.3978
# Longtitude    145.52635

# %% [markdown]
# Correlations

# %%
numeric_data = housing_data.select(numeric_features).toPandas()
axs = pd.plotting.scatter_matrix(numeric_data, figsize=(8, 8));

# Rotate axis labels and remove axis ticks
n = len(numeric_data.columns)
for i in range(n):
    v = axs[i, 0]
    v.yaxis.label.set_rotation(0)
    v.yaxis.label.set_ha('right')
    v.set_yticks(())
    h = axs[n-1, i]
    h.xaxis.label.set_rotation(90)
    h.set_xticks(())

# %% [markdown]
# We see that there Rooms and Bedroom2 may be highly correlated independent variables. So we can investigate them further.

# %%
correlated_data = housing_data.select(["Rooms", "Bedroom2"]).toPandas().dropna()
correlated_data["Rooms"].corr(correlated_data["Bedroom2"])
# Out:
# 0.9587411322746887

# %% [markdown]
# We see that Rooms and Bedroom2 are highly correlated because the correlation value calculated is very close to 1. So we will drop Bedroom2. We will also drop Latitude and Longtitude because they will not be useful for the model.

# %%
housing_data = housing_data.drop("Bedroom2").drop("Lattitude").drop("Longtitude")
housing_data.printSchema()
# Out:
# root
#  |-- Suburb: string (nullable = true)
#  |-- Address: string (nullable = true)
#  |-- Rooms: integer (nullable = true)
#  |-- Type: string (nullable = true)
#  |-- Price: integer (nullable = true)
#  |-- Method: string (nullable = true)
#  |-- SellerG: string (nullable = true)
#  |-- Date: date (nullable = true)
#  |-- Distance: double (nullable = true)
#  |-- Postcode: string (nullable = true)
#  |-- Bathroom: integer (nullable = true)
#  |-- Car: integer (nullable = true)
#  |-- Landsize: integer (nullable = true)
#  |-- BuildingArea: double (nullable = true)
#  |-- YearBuilt: integer (nullable = true)
#  |-- CouncilArea: string (nullable = true)
#  |-- Regionname: string (nullable = true)
#  |-- Propertycount: string (nullable = true)

# %% [markdown]
# #### Working with missing data
# We will first investigate the percentage of missing values in each column.

# %%
housing_data.select(*((sum(col(c).isNull().cast("int"))/housing_data.count()*100).alias(c) for c in housing_data.columns)).toPandas().transpose()
# Out:
#                        0
# Suburb          0.000000
# Address         0.000000
# Rooms           0.000000
# Type            0.000000
# Price           0.000000
# Method          0.000000
# SellerG         0.000000
# Date            0.000000
# Distance        0.003670
# Postcode        0.000000
# Bathroom       23.661321
# Car            25.044959
# Landsize       34.003744
# BuildingArea   60.891107
# YearBuilt      55.650163
# CouncilArea     0.000000
# Regionname      0.000000
# Propertycount   0.000000

# %% [markdown]
# We can see that the BuildingArea and YearBuilt have a high percentage of null values and so we will drop them.

# %%
housing_data = housing_data.select([c for c in housing_data.columns if c not in ["BuildingArea", "YearBuilt"]])
housing_data.printSchema()
# Out:
# root
#  |-- Suburb: string (nullable = true)
#  |-- Address: string (nullable = true)
#  |-- Rooms: integer (nullable = true)
#  |-- Type: string (nullable = true)
#  |-- Price: integer (nullable = true)
#  |-- Method: string (nullable = true)
#  |-- SellerG: string (nullable = true)
#  |-- Date: date (nullable = true)
#  |-- Distance: double (nullable = true)
#  |-- Postcode: string (nullable = true)
#  |-- Bathroom: integer (nullable = true)
#  |-- Car: integer (nullable = true)
#  |-- Landsize: integer (nullable = true)
#  |-- CouncilArea: string (nullable = true)
#  |-- Regionname: string (nullable = true)
#  |-- Propertycount: string (nullable = true)

# %% [markdown]
# We will fill in the missing values for Bathroom, Car and Landsize with the median values for each column.

# %%
from pyspark.sql.functions import mean
cols = ["Bathroom", "Car", "Landsize", "Distance"]
median_data = [median[0] for median in housing_data.approxQuantile(cols, [0.5], 0)]
median_dict = dict(zip(cols, median_data))
    
print(median_dict)
housing_data = housing_data.fillna(median_dict)
# Out:
# {'Bathroom': 1.0, 'Car': 2.0, 'Landsize': 512.0, 'Distance': 10.5}

# %%
housing_data.select(*((sum(col(c).isNull().cast("int"))/housing_data.count()*100).alias(c) for c in housing_data.columns)).toPandas().transpose()
# Out:
#                  0
# Suburb         0.0
# Address        0.0
# Rooms          0.0
# Type           0.0
# Price          0.0
# Method         0.0
# SellerG        0.0
# Date           0.0
# Distance       0.0
# Postcode       0.0
# Bathroom       0.0
# Car            0.0
# Landsize       0.0
# CouncilArea    0.0
# Regionname     0.0
# Propertycount  0.0

# %% [markdown]
# ### Dealing with Outliers
# We compute the IQR and then remove outlier values which are values that are outside of the range Q1 - 1.5 * IQR < x < Q3  + 1.5 * IQR.

# %%
numeric_features = [t[0] for t in housing_data.dtypes if t[1] == 'int' or t[1] == 'double']
bounds = {
    c: dict(
        zip(["q1", "q3"], housing_data.approxQuantile(c, [0.25, 0.75], 0))
    )
    for c in numeric_features
}
for c in bounds:
    iqr = bounds[c]['q3'] - bounds[c]['q1']
    bounds[c]['lower'] = bounds[c]['q1'] - (iqr * 1.5)
    bounds[c]['upper'] = bounds[c]['q3'] + (iqr * 1.5)
print(bounds)
# Out:
# {'Rooms': {'q1': 2.0, 'q3': 4.0, 'lower': -1.0, 'upper': 7.0}, 'Price': {'q1': 635000.0, 'q3': 1295000.0, 'lower': -355000.0, 'upper': 2285000.0}, 'Distance': {'q1': 6.4, 'q3': 14.0, 'lower': -4.999999999999998, 'upper': 25.4}, 'Bathroom': {'q1': 1.0, 'q3': 2.0, 'lower': -0.5, 'upper': 3.5}, 'Car': {'q1': 1.0, 'q3': 2.0, 'lower': -0.5, 'upper': 3.5}, 'Landsize': {'q1': 351.0, 'q3': 592.0, 'lower': -10.5, 'upper': 953.5}}

# %%
housing_data = housing_data.where(col("Rooms").between(bounds["Rooms"]['lower'], bounds["Rooms"]['upper']) &
                                  col("Price").between(bounds["Price"]['lower'], bounds["Price"]['upper']) &
                                  col("Bathroom").between(bounds["Bathroom"]['lower'], bounds["Bathroom"]['upper']) &
                                  col("Car").between(bounds["Car"]['lower'], bounds["Car"]['upper']) &
                                  col("Landsize").between(bounds["Landsize"]['lower'], bounds["Landsize"]['upper']))

# %%
print((housing_data.count(), len(housing_data.columns)))
# Out:
# (24083, 16)

# %% [markdown]
# ####  Encode categorical data

# %%
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler

categorical_features = [t[0] for t in housing_data.dtypes if t[1] == 'string']
stages = []

for c in categorical_features:
    stringIndexer = StringIndexer(inputCol = c, outputCol = c + 'Index')
    indexed = stringIndexer.fit(housing_data).transform(housing_data)
    encoder = OneHotEncoder(inputCols=[stringIndexer.getOutputCol()], outputCols=[c + "classVec"])
    housing_data = encoder.fit(indexed).transform(indexed)
assemblerInputs = [c + "classVec" for c in categorical_features] + numeric_features
assembler = VectorAssembler(inputCols=assemblerInputs, outputCol="features")
output = assembler.transform(housing_data)
output.select("features", "Price").show()
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# <ipython-input-143-728db636ac75> in <module>
#      11 assemblerInputs = [c + "classVec" for c in categorical_features] + numeric_features
#      12 assembler = VectorAssembler(inputCols=assemblerInputs, outputCol="features")
# ---> 13 output = assembler.transform(housing_data)
#      14 output.select("features", "Price").show()
#
# /usr/local/spark/python/pyspark/ml/base.py in transform(self, dataset, params)
#     168                 return self.copy(params)._transform(dataset)
#     169             else:
# --> 170                 return self._transform(dataset)
#     171         else:
#     172             raise ValueError("Params must be a param map but got %s." % type(params))
#
# /usr/local/spark/python/pyspark/ml/wrapper.py in _transform(self, dataset)
#     336     def _transform(self, dataset):
#     337         self._transfer_params_to_java()
# --> 338         return DataFrame(self._java_obj.transform(dataset._jdf), dataset.sql_ctx)
#     339
#     340
#
# /usr/local/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /usr/local/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#     135                 # Hide where the exception came from that shows a non-Pythonic
#     136                 # JVM exception message.
# --> 137                 raise_from(converted)
#     138             else:
#     139                 raise
#
# /usr/local/spark/python/pyspark/sql/utils.py in raise_from(e)
#
# IllegalArgumentException: SuburbclassVec does not exist. Available: Suburb, Address, Rooms, Type, Price, Method, SellerG, Date, Distance, Postcode, Bathroom, Car, Landsize, CouncilArea, Regionname, Propertycount
